# %%
# !pip install  llama-index-experimental llama-index-llms-gemini

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import pandas as pd
from llama_index.experimental.query_engine import PandasQueryEngine

df = pd.read_csv("/content/(CSV) BurnabySingleFamilyHousePrice.csv")

# %%
df['Sold Price'] = df['Sold Price'].str.replace(',', '')
df['Sold Price'] = df['Sold Price'].str.replace('$', '').astype(int)

# %%
import os

os.environ["LLAMA_CLOUD_API_KEY"] = "llx-ZkhJIBo5MR8XoVo6RnJvaQdtUySysluPWivHopC088TTID54"
os.environ['GOOGLE_API_KEY'] = 'AIzaSyCKnwTG-kvt2B6vH0OBMRdUhhsP3lZHGic'

# %%
from llama_index.llms.gemini import Gemini
llm = Gemini(model="models/gemini-1.0-pro", temperature=0.9)

# %%
query_engine = PandasQueryEngine(df=df, verbose=False, synthesize_response=True, llm = llm)
response = query_engine.query("plot the relationship between price with number of beadroom.")
print(response)
# Out:
# The relationship between price and number of bedrooms is a significant factor in real estate. In general, the more bedrooms a house has, the higher the price. This is because bedrooms are seen as a valuable amenity by many buyers, and they are willing to pay more for them. However, the relationship between price and number of bedrooms is not always linear. In some cases, the price of a house may actually decrease as the number of bedrooms increases. This is because buyers may be willing to pay more for a house with a certain number of bedrooms, but they may not be willing to pay more for a house with more bedrooms than they need.
